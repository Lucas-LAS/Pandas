# %% [markdown]
# # Manipulando estilo

# %%
import pandas as pd
import re

link_filme ="https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula4.2/movies.csv" 
filmes= pd.read_csv(link_filme)
filmes.columns=['ID_Filmes','Nome','Género']
filmes.head()
# Out:
#    ID_Filmes  ...                                       Género
# 0          1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1          2  ...                   Adventure|Children|Fantasy
# 2          3  ...                               Comedy|Romance
# 3          4  ...                         Comedy|Drama|Romance
# 4          5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
link_notas ='https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula4.1/ratings.csv'
notas = pd.read_csv(link_notas)
notas.columns = ['ID_Usuario','Filme','Nota','Data']
notas.head()
# Out:
#    ID_Usuario  Filme  Nota       Data
# 0           1      1   4.0  964982703
# 1           1      3   4.0  964981247
# 2           1      6   4.0  964982224
# 3           1     47   5.0  964983815
# 4           1     50   5.0  964982931

# %%
def color_red(val):
  color = 'red' if val<2 else 'black'
  return 'color: %s'% color

# %%
s=notas.head().style.applymap(color_red,subset=['ID_Usuario'])
s
# Out:
# <style  type="text/css" >
#     #T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row0_col0 {
#             color:  red;
#         }    #T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row1_col0 {
#             color:  red;
#         }    #T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row2_col0 {
#             color:  red;
#         }    #T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row3_col0 {
#             color:  red;
#         }    #T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row4_col0 {
#             color:  red;
#         }</style><table id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID_Usuario</th>        <th class="col_heading level0 col1" >Filme</th>        <th class="col_heading level0 col2" >Nota</th>        <th class="col_heading level0 col3" >Data</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row0_col2" class="data row0 col2" >4</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row0_col3" class="data row0 col3" >964982703</td>
#             </tr>
#             <tr>
#                         <th id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row1_col1" class="data row1 col1" >3</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row1_col2" class="data row1 col2" >4</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row1_col3" class="data row1 col3" >964981247</td>
#             </tr>
#             <tr>
#                         <th id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row2_col0" class="data row2 col0" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row2_col1" class="data row2 col1" >6</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row2_col2" class="data row2 col2" >4</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row2_col3" class="data row2 col3" >964982224</td>
#             </tr>
#             <tr>
#                         <th id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row3_col1" class="data row3 col1" >47</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row3_col2" class="data row3 col2" >5</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row3_col3" class="data row3 col3" >964983815</td>
#             </tr>
#             <tr>
#                         <th id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row4_col1" class="data row4 col1" >50</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row4_col2" class="data row4 col2" >5</td>
#                         <td id="T_56e3c9ec_e44e_11e9_8c24_0242ac1c0002row4_col3" class="data row4 col3" >964982931</td>
#             </tr>
#     </tbody></table>

# %%
def testes_nome(name):
  
  
  cor = 'red' if re.search(r'Toy Story[.]*', name)  else 'blue'
 
  return 'color:%s' % cor

# %%
n=filmes.head().style.applymap(testes_nome,subset=['Nome'])
n
# Out:
# <style  type="text/css" >
#     #T_5dd70944_e44e_11e9_8c24_0242ac1c0002row0_col1 {
#             color: red;
#         }    #T_5dd70944_e44e_11e9_8c24_0242ac1c0002row1_col1 {
#             color: blue;
#         }    #T_5dd70944_e44e_11e9_8c24_0242ac1c0002row2_col1 {
#             color: blue;
#         }    #T_5dd70944_e44e_11e9_8c24_0242ac1c0002row3_col1 {
#             color: blue;
#         }    #T_5dd70944_e44e_11e9_8c24_0242ac1c0002row4_col1 {
#             color: blue;
#         }</style><table id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ID_Filmes</th>        <th class="col_heading level0 col1" >Nome</th>        <th class="col_heading level0 col2" >Género</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row0_col1" class="data row0 col1" >Toy Story (1995)</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row0_col2" class="data row0 col2" >Adventure|Animation|Children|Comedy|Fantasy</td>
#             </tr>
#             <tr>
#                         <th id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row1_col1" class="data row1 col1" >Jumanji (1995)</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row1_col2" class="data row1 col2" >Adventure|Children|Fantasy</td>
#             </tr>
#             <tr>
#                         <th id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row2_col1" class="data row2 col1" >Grumpier Old Men (1995)</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row2_col2" class="data row2 col2" >Comedy|Romance</td>
#             </tr>
#             <tr>
#                         <th id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row3_col1" class="data row3 col1" >Waiting to Exhale (1995)</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row3_col2" class="data row3 col2" >Comedy|Drama|Romance</td>
#             </tr>
#             <tr>
#                         <th id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row4_col1" class="data row4 col1" >Father of the Bride Part II (1995)</td>
#                         <td id="T_5dd70944_e44e_11e9_8c24_0242ac1c0002row4_col2" class="data row4 col2" >Comedy</td>
#             </tr>
#     </tbody></table>

# %%
from datetime import datetime
d1= datetime.now( )
valores = pd.DataFrame({'Data':['2019-09-24 13:06:18','2019-09-24 12:59:56',
'2019-09-24 13:04:44',
'2019-09-24 13:06:44',
'2019-09-24 13:05:15',
'2019-09-24 13:05:39',
'2019-09-24 13:06:23',
'2019-09-24 13:05:44',
'2019-09-24 13:02:17',
'2019-09-24 13:06:08',
'2019-09-24 13:05:14',
'2019-09-24 13:05:32',
'2019-09-24 13:06:27',
'2019-09-28 10:05:57'],
'Placa':['FCL-5195',
'GCN-2159',
'FNE-4788',
'FST-7136',
'FOM-1791',
'FBV-1459',
'FSR-8899',
'GCX-9849',
'GCU-1666',
'FPF-9246',
'FCE-3543',
'FPC-9995',
'GFS-8513',
'GCV-9512']})
valores.head()
# Out:
#                   Data     Placa
# 0  2019-09-24 13:06:18  FCL-5195
# 1  2019-09-24 12:59:56  GCN-2159
# 2  2019-09-24 13:04:44  FNE-4788
# 3  2019-09-24 13:06:44  FST-7136
# 4  2019-09-24 13:05:15  FOM-1791

# %% [markdown]
# ## Background-color
# >  Usa o mesmo metodo para coloca estilos na fontes utilizando o biblioteca **pandas** e função **style.applymap()** unica diferença que utilizamos o ***background-color*** no lugar de **color**
# >> *Conforme Exemplo abaixo*

# %%
def hora(data_hora):
  hora=datetime.strptime(data_hora,'%Y-%m-%d %H:%M:%S')
  com_hora=abs((datetime.today( )-hora).days)
  cor = 'red' if com_hora>=1 else 'green'
  return 'background-color : %s' % cor

# %%
s_valores =valores.style.applymap(hora,subset='Data')
s_valores
# Out:
# <style  type="text/css" >
#     #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row0_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row1_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row2_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row3_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row4_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row5_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row6_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row7_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row8_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row9_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row10_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row11_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row12_col0 {
#             background-color :  red;
#         }    #T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row13_col0 {
#             background-color :  red;
#         }</style><table id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Data</th>        <th class="col_heading level0 col1" >Placa</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row0_col0" class="data row0 col0" >2019-09-24 13:06:18</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row0_col1" class="data row0 col1" >FCL-5195</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row1_col0" class="data row1 col0" >2019-09-24 12:59:56</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row1_col1" class="data row1 col1" >GCN-2159</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row2_col0" class="data row2 col0" >2019-09-24 13:04:44</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row2_col1" class="data row2 col1" >FNE-4788</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row3_col0" class="data row3 col0" >2019-09-24 13:06:44</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row3_col1" class="data row3 col1" >FST-7136</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row4_col0" class="data row4 col0" >2019-09-24 13:05:15</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row4_col1" class="data row4 col1" >FOM-1791</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row5_col0" class="data row5 col0" >2019-09-24 13:05:39</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row5_col1" class="data row5 col1" >FBV-1459</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row6_col0" class="data row6 col0" >2019-09-24 13:06:23</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row6_col1" class="data row6 col1" >FSR-8899</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row7_col0" class="data row7 col0" >2019-09-24 13:05:44</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row7_col1" class="data row7 col1" >GCX-9849</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row8_col0" class="data row8 col0" >2019-09-24 13:02:17</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row8_col1" class="data row8 col1" >GCU-1666</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row9_col0" class="data row9 col0" >2019-09-24 13:06:08</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row9_col1" class="data row9 col1" >FPF-9246</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row10_col0" class="data row10 col0" >2019-09-24 13:05:14</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row10_col1" class="data row10 col1" >FCE-3543</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row11_col0" class="data row11 col0" >2019-09-24 13:05:32</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row11_col1" class="data row11 col1" >FPC-9995</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row12_col0" class="data row12 col0" >2019-09-24 13:06:27</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row12_col1" class="data row12 col1" >GFS-8513</td>
#             </tr>
#             <tr>
#                         <th id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row13_col0" class="data row13 col0" >2019-09-28 10:05:57</td>
#                         <td id="T_6b79cc08_e44e_11e9_8c24_0242ac1c0002row13_col1" class="data row13 col1" >GCV-9512</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Profiling

# %%
import pandas_profiling
pandas_profiling.ProfileReport(notas)
# sava em html isso depois
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>100836 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>3.1 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>32.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_Data">Data<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>85043</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>84.3%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n)</th>
#                     <td>0</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Infinite (n)</th>
#                     <td>0</td>
#                 </tr>
#             </table>
#
#         </div>
#         <div class="col-sm-6">
#             <table class="stats ">
#
#                 <tr>
#                     <th>Mean</th>
#                     <td>1205900000</td>

# %% [markdown]
# ## ProfileReport
# > Criar um analise da estrutura do DataFrame, exibindo informções de colunas até tipo de dados realação entre a colunas

# %% [markdown]
# # Informações basica do dataframe

# %%
notas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
# ID_Usuario    100836 non-null int64
# Filme         100836 non-null int64
# Nota          100836 non-null float64
# Data          100836 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
notas.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e38242ef813f> in <module>()
# ----> 1 notas.index()
#
# TypeError: 'RangeIndex' object is not callable

# %% [markdown]
# > Metodo **info()** exibir a estrutura de inicio e fim mostrando sequência da ordem do index. Todas essas informações são baseadas no index e não na quantidade de item no dataframe.
#
# >> **Exemplo** O dataframe ***notas*** inicia seu index no 0, mas caso dataframe iniciasse no 1 e pulasse em dois em dois o indiice mostarias informações diferente conforme exemplo a baixo.

# %%
exemplo_info = pd.DataFrame({'Indice':[1,3,5,7],'nome':['lucas','eduarda','jose','maria'],'idade':[26,22,60,56],'sexo':['M','F','M','F']})
exemplo_info.set_index('Indice', inplace = True) # inplace altera o DataFrame raiz não é necessário armazenar e outra variavel
exemplo_info
# Out:
#            nome  idade sexo
# Indice
# 1         lucas     26    M
# 3       eduarda     22    F
# 5          jose     60    M
# 7         maria     56    F

# %%
exemplo_info.index # Exibir a estrutura da coluna indice
# Out:
# Int64Index([1, 3, 5, 7], dtype='int64', name='Indice')

# %% [markdown]
# ### ***Values*** Mostrar valores exibir o valores do DataFrame e forma de lista, mas sem o index

# %%
exemplo_info.values
# Out:
# array([['lucas'],
#        ['eduarda'],
#        ['jose'],
#        ['maria']], dtype=object)

# %% [markdown]
# ### ***Columns*** Mostra em formato de lista o rotulos da colunas sem o index

# %%
exemplo_info.columns
# Out:
# Index(['nome', 'idade', 'sexo'], dtype='object')

# %% [markdown]
# ## Usando loc e Iloc

# %% [markdown]
# > O loc realizar a buscar baseado no indice definido da DataFrame.
# >> Lembrando caso não seja passado nenhum indice python vai retorna um erro

# %% [markdown]
# ### loc

# %%
exemplo_info.loc[[1,3,5]]
# Out:
#            nome  idade sexo
# Indice
# 1         lucas     26    M
# 3       eduarda     22    F
# 5          jose     60    M

# %% [markdown]
# Também podemos chama por linhas ou no caso pelo dado

# %%
exemplo_2 = exemplo_info.set_index('nome')
exemplo_2
# Out:
#          idade sexo
# nome
# lucas       26    M
# eduarda     22    F
# jose        60    M
# maria       56    F

# %%
exemplo_2.loc['lucas']
# Out:
# idade    26
# sexo      M
# Name: lucas, dtype: object

# %% [markdown]
# >**Pode ser passados mais de item para loc**
# >**No codigo a baixo só mostrar a coluna que foi informada no segundo 'lista' ou 'paramentos'**
# >> ***Lembrando que a primeira lista se refere a linha e a segunda a coluna***
# >>> *O indice e sempre mostrado*

# %%
exemplo_2.loc[['lucas','maria'],['idade']]
# Out:
#        idade
# nome
# lucas     26
# maria     56

# %% [markdown]
# ### Com o loc podemos cobinar operações lógicas.

# %%
exemplo_2.loc[(exemplo_2['idade'])<=26]
# Out:
#          idade sexo
# nome
# lucas       26    M
# eduarda     22    F

# %% [markdown]
# ### Usando Iloc

# %% [markdown]
# Diferente do loc o iloc não buscar pelo index, mas lista todos os item do DataFrame de acordo com sua posição como se fosse uma lista python, primeiro indice 0 somando um a cada item .

# %%
exemplo_2.iloc[0:4]
# Out:
#          idade sexo
# nome
# lucas       26    M
# eduarda     22    F
# jose        60    M
# maria       56    F
